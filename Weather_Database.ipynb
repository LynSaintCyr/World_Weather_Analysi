# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs =zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 726

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key_

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key_
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e6d6501ce86f911bd703e33bcc123e37

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]  
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dakar
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | volgorechensk
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | dingle
# Processing Record 8 of Set 1 | inuvik
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | port hardy
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | quelimane
# Processing Record 14 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | hami
# Processing Record 17 of Set 1 | azul
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | lianzhou
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | kahului
# Processing Record 22 of Set 1 | rawson
# Processing Record 23 of Set 1 | umm bab
# Processing Record 24 of Set 1 | lasa
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | ostersund
# Processing Record 27 of Set 1 | pula
# Processing Record 28 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | banjar
# Processing Record 31 of Set 1 | san cristobal
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | coquimbo
# Processing Record 34 of Set 1 | lushunkou
# City not found. Skipping...
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 1 | vanderhoof
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 1 | medicine hat
# Processing Record 43 of Set 1 | katsuura
# Processing Record 44 of Set 1 | prescott
# Processing Record 45 of Set 1 | phan thiet
# Processing Record 46 of Set 1 | vanimo
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | kautokeino
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | lac du bonnet
# Processing Record 3 of Set 2 | pampierstad
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | chipinge
# Processing Record 7 of Set 2 | kolosovka
# Processing Record 8 of Set 2 | sitka
# Processing Record 9 of Set 2 | yulara
# Processing Record 10 of Set 2 | nikolskoye
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 2 | huarmey
# Processing Record 14 of Set 2 | maralal
# Processing Record 15 of Set 2 | laguna
# Processing Record 16 of Set 2 | sabha
# Processing Record 17 of Set 2 | villarrica
# Processing Record 18 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | esperance
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | bradford
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | sola
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | asau
# Processing Record 29 of Set 2 | portland
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | geraldton
# Processing Record 32 of Set 2 | severodvinsk
# Processing Record 33 of Set 2 | caravelas
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | kenai
# Processing Record 36 of Set 2 | kamaishi
# Processing Record 37 of Set 2 | talnakh
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | paragominas
# Processing Record 40 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | mokama
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | amahai
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | gornoye loo
# Processing Record 47 of Set 2 | grand gaube
# Processing Record 48 of Set 2 | trairi
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | tancheng
# Processing Record 1 of Set 3 | amatlan
# City not found. Skipping...
# Processing Record 2 of Set 3 | astolfo dutra
# Processing Record 3 of Set 3 | schmolln
# Processing Record 4 of Set 3 | victoria
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 3 | fez
# Processing Record 8 of Set 3 | taltal
# Processing Record 9 of Set 3 | fonte boa
# Processing Record 10 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | nohar
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | makakilo city
# Processing Record 16 of Set 3 | mitsamiouli
# Processing Record 17 of Set 3 | ponta delgada
# Processing Record 18 of Set 3 | tumsar
# Processing Record 19 of Set 3 | hofn
# Processing Record 20 of Set 3 | opuwo
# Processing Record 21 of Set 3 | emmett
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | barrow
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | pochutla
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | acapulco
# Processing Record 32 of Set 3 | vaini
# Processing Record 33 of Set 3 | yerbogachen
# Processing Record 34 of Set 3 | nanakuli
# Processing Record 35 of Set 3 | digha
# Processing Record 36 of Set 3 | mezen
# Processing Record 37 of Set 3 | normandin
# Processing Record 38 of Set 3 | iranshahr
# Processing Record 39 of Set 3 | gobabis
# Processing Record 40 of Set 3 | el cope
# Processing Record 41 of Set 3 | ribeira grande
# Processing Record 42 of Set 3 | villaviciosa
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | imeni poliny osipenko
# Processing Record 45 of Set 3 | alto vera
# City not found. Skipping...
# Processing Record 46 of Set 3 | coihaique
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | antofagasta
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | lovozero
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | sidrolandia
# Processing Record 3 of Set 4 | hamilton
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | naze
# Processing Record 6 of Set 4 | reyes
# Processing Record 7 of Set 4 | ouargaye
# Processing Record 8 of Set 4 | matara
# Processing Record 9 of Set 4 | miri
# Processing Record 10 of Set 4 | bayir
# Processing Record 11 of Set 4 | saint-pierre
# Processing Record 12 of Set 4 | winchester
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | mananjary
# Processing Record 15 of Set 4 | maniitsoq
# Processing Record 16 of Set 4 | corralillo
# Processing Record 17 of Set 4 | ugoofaaru
# Processing Record 18 of Set 4 | tazovskiy
# Processing Record 19 of Set 4 | alta floresta
# Processing Record 20 of Set 4 | havelock
# Processing Record 21 of Set 4 | eirunepe
# Processing Record 22 of Set 4 | ayagoz
# Processing Record 23 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 4 | hovd
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | talcahuano
# Processing Record 28 of Set 4 | coahuayana
# Processing Record 29 of Set 4 | solnechnyy
# Processing Record 30 of Set 4 | hasaki
# Processing Record 31 of Set 4 | warrington
# Processing Record 32 of Set 4 | vila velha
# Processing Record 33 of Set 4 | burica
# City not found. Skipping...
# Processing Record 34 of Set 4 | jabinyanah
# Processing Record 35 of Set 4 | russell
# Processing Record 36 of Set 4 | soyo
# Processing Record 37 of Set 4 | port said
# Processing Record 38 of Set 4 | fairbanks
# Processing Record 39 of Set 4 | flinders
# Processing Record 40 of Set 4 | namatanai
# Processing Record 41 of Set 4 | sarankhola
# Processing Record 42 of Set 4 | kavaratti
# Processing Record 43 of Set 4 | saskylakh
# Processing Record 44 of Set 4 | abu samrah
# Processing Record 45 of Set 4 | necochea
# Processing Record 46 of Set 4 | nikolayevsk-na-amure
# Processing Record 47 of Set 4 | amapa
# Processing Record 48 of Set 4 | kavieng
# Processing Record 49 of Set 4 | vilyuysk
# Processing Record 50 of Set 4 | atar
# Processing Record 1 of Set 5 | quirinopolis
# Processing Record 2 of Set 5 | mount isa
# Processing Record 3 of Set 5 | yaring
# Processing Record 4 of Set 5 | palmas
# Processing Record 5 of Set 5 | qaqortoq
# Processing Record 6 of Set 5 | fukue
# Processing Record 7 of Set 5 | kupang
# Processing Record 8 of Set 5 | college
# Processing Record 9 of Set 5 | veraval
# Processing Record 10 of Set 5 | dicabisagan
# Processing Record 11 of Set 5 | srednekolymsk
# Processing Record 12 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 5 | camana
# Processing Record 14 of Set 5 | maldonado
# Processing Record 15 of Set 5 | dabhol
# Processing Record 16 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 5 | coulihaut
# City not found. Skipping...
# Processing Record 18 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 5 | birao
# Processing Record 20 of Set 5 | carnarvon
# Processing Record 21 of Set 5 | cap malheureux
# Processing Record 22 of Set 5 | bonthe
# Processing Record 23 of Set 5 | ayan
# Processing Record 24 of Set 5 | damaturu
# Processing Record 25 of Set 5 | airai
# Processing Record 26 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 5 | constitucion
# Processing Record 28 of Set 5 | taoudenni
# Processing Record 29 of Set 5 | olavarria
# Processing Record 30 of Set 5 | jumla
# Processing Record 31 of Set 5 | svetlogorsk
# Processing Record 32 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 5 | emmen
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | puerto colombia
# Processing Record 37 of Set 5 | moose factory
# Processing Record 38 of Set 5 | gambela
# Processing Record 39 of Set 5 | goundam
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | dzhebariki-khaya
# Processing Record 42 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 5 | sao joao da barra
# Processing Record 44 of Set 5 | port elizabeth
# Processing Record 45 of Set 5 | henties bay
# Processing Record 46 of Set 5 | hornepayne
# Processing Record 47 of Set 5 | broken hill
# Processing Record 48 of Set 5 | mandurah
# Processing Record 49 of Set 5 | alyangula
# Processing Record 50 of Set 5 | talaya
# Processing Record 1 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 2 of Set 6 | bati
# Processing Record 3 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 6 | cayenne
# Processing Record 5 of Set 6 | wooster
# Processing Record 6 of Set 6 | kathu
# Processing Record 7 of Set 6 | shache
# Processing Record 8 of Set 6 | roebourne
# Processing Record 9 of Set 6 | abha
# Processing Record 10 of Set 6 | sinnamary
# Processing Record 11 of Set 6 | provideniya
# Processing Record 12 of Set 6 | ancud
# Processing Record 13 of Set 6 | yar-sale
# Processing Record 14 of Set 6 | oistins
# Processing Record 15 of Set 6 | auki
# Processing Record 16 of Set 6 | bahia honda
# Processing Record 17 of Set 6 | sistranda
# Processing Record 18 of Set 6 | muzquiz
# City not found. Skipping...
# Processing Record 19 of Set 6 | lensk
# Processing Record 20 of Set 6 | whitehorse
# Processing Record 21 of Set 6 | listvyanskiy
# Processing Record 22 of Set 6 | lagoa
# Processing Record 23 of Set 6 | nanyang
# Processing Record 24 of Set 6 | mogadishu
# Processing Record 25 of Set 6 | oume
# Processing Record 26 of Set 6 | ravar
# Processing Record 27 of Set 6 | saint george
# Processing Record 28 of Set 6 | havre-saint-pierre
# Processing Record 29 of Set 6 | los llanos de aridane
# Processing Record 30 of Set 6 | umm lajj
# Processing Record 31 of Set 6 | umea
# Processing Record 32 of Set 6 | chokurdakh
# Processing Record 33 of Set 6 | kerouane
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | karratha
# Processing Record 36 of Set 6 | remontnoye
# Processing Record 37 of Set 6 | sarangani
# Processing Record 38 of Set 6 | khandbari
# Processing Record 39 of Set 6 | villamontes
# Processing Record 40 of Set 6 | eyl
# Processing Record 41 of Set 6 | fortuna
# Processing Record 42 of Set 6 | meulaboh
# Processing Record 43 of Set 6 | batarci
# Processing Record 44 of Set 6 | qaanaaq
# Processing Record 45 of Set 6 | port hedland
# Processing Record 46 of Set 6 | bambous virieux
# Processing Record 47 of Set 6 | belyy yar
# Processing Record 48 of Set 6 | turayf
# Processing Record 49 of Set 6 | hirara
# Processing Record 50 of Set 6 | sal rei
# Processing Record 1 of Set 7 | taos
# Processing Record 2 of Set 7 | presidencia roque saenz pena
# Processing Record 3 of Set 7 | kovdor
# Processing Record 4 of Set 7 | leningradskiy
# Processing Record 5 of Set 7 | hadejia
# Processing Record 6 of Set 7 | mar del plata
# Processing Record 7 of Set 7 | vardo
# Processing Record 8 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 7 | the valley
# Processing Record 10 of Set 7 | itarema
# Processing Record 11 of Set 7 | motygino
# Processing Record 12 of Set 7 | bengkulu
# Processing Record 13 of Set 7 | kodiak
# Processing Record 14 of Set 7 | gibara
# Processing Record 15 of Set 7 | del rio
# Processing Record 16 of Set 7 | buala
# Processing Record 17 of Set 7 | ostrovnoy
# Processing Record 18 of Set 7 | pevek
# Processing Record 19 of Set 7 | sobolevo
# Processing Record 20 of Set 7 | nishihara
# Processing Record 21 of Set 7 | piossasco
# Processing Record 22 of Set 7 | zyryanka
# Processing Record 23 of Set 7 | manica
# Processing Record 24 of Set 7 | saint-philippe
# Processing Record 25 of Set 7 | sabang
# Processing Record 26 of Set 7 | beloha
# Processing Record 27 of Set 7 | lichinga
# Processing Record 28 of Set 7 | mendi
# Processing Record 29 of Set 7 | zilair
# Processing Record 30 of Set 7 | san vicente
# Processing Record 31 of Set 7 | morropon
# Processing Record 32 of Set 7 | po
# City not found. Skipping...
# Processing Record 33 of Set 7 | mount gambier
# Processing Record 34 of Set 7 | capao da canoa
# Processing Record 35 of Set 7 | quatre cocos
# Processing Record 36 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 7 | hambantota
# Processing Record 38 of Set 7 | aklavik
# Processing Record 39 of Set 7 | the pas
# Processing Record 40 of Set 7 | ewa beach
# Processing Record 41 of Set 7 | okha
# Processing Record 42 of Set 7 | hayato
# City not found. Skipping...
# Processing Record 43 of Set 7 | safaga
# Processing Record 44 of Set 7 | kununurra
# Processing Record 45 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 7 | goksun
# Processing Record 47 of Set 7 | molina
# Processing Record 48 of Set 7 | beloeil
# Processing Record 49 of Set 7 | san jose
# Processing Record 50 of Set 7 | nehe
# Processing Record 1 of Set 8 | kabala
# Processing Record 2 of Set 8 | progreso
# Processing Record 3 of Set 8 | long beach
# Processing Record 4 of Set 8 | ungka
# City not found. Skipping...
# Processing Record 5 of Set 8 | ust-barguzin
# Processing Record 6 of Set 8 | trinidad
# Processing Record 7 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 8 | san rafael
# Processing Record 9 of Set 8 | mehamn
# Processing Record 10 of Set 8 | springfield
# Processing Record 11 of Set 8 | yinchuan
# Processing Record 12 of Set 8 | rubik
# Processing Record 13 of Set 8 | tonj
# Processing Record 14 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 8 | anadyr
# Processing Record 16 of Set 8 | san patricio
# Processing Record 17 of Set 8 | vao
# Processing Record 18 of Set 8 | touros
# Processing Record 19 of Set 8 | udalguri
# Processing Record 20 of Set 8 | tres lagoas
# Processing Record 21 of Set 8 | salalah
# Processing Record 22 of Set 8 | leshukonskoye
# Processing Record 23 of Set 8 | baculin
# Processing Record 24 of Set 8 | clyde river
# Processing Record 25 of Set 8 | scarborough
# Processing Record 26 of Set 8 | tignere
# Processing Record 27 of Set 8 | ambon
# Processing Record 28 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 29 of Set 8 | cariamanga
# Processing Record 30 of Set 8 | mezhdurechenskiy
# Processing Record 31 of Set 8 | slubice
# Processing Record 32 of Set 8 | sept-iles
# Processing Record 33 of Set 8 | dzerzhinskoye
# Processing Record 34 of Set 8 | salaga
# Processing Record 35 of Set 8 | honningsvag
# Processing Record 36 of Set 8 | baiyin
# Processing Record 37 of Set 8 | alexandria
# Processing Record 38 of Set 8 | pervomayskoye
# Processing Record 39 of Set 8 | anzio
# Processing Record 40 of Set 8 | marawi
# Processing Record 41 of Set 8 | fort nelson
# Processing Record 42 of Set 8 | merauke
# Processing Record 43 of Set 8 | manicore
# Processing Record 44 of Set 8 | madang
# Processing Record 45 of Set 8 | manakara
# Processing Record 46 of Set 8 | ulladulla
# Processing Record 47 of Set 8 | new norfolk
# Processing Record 48 of Set 8 | baghdad
# Processing Record 49 of Set 8 | tuatapere
# Processing Record 50 of Set 8 | tommot
# Processing Record 1 of Set 9 | floro
# Processing Record 2 of Set 9 | charters towers
# Processing Record 3 of Set 9 | calabozo
# Processing Record 4 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 9 | san antonio
# Processing Record 7 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 9 | ust-uda
# Processing Record 9 of Set 9 | birin
# Processing Record 10 of Set 9 | poum
# Processing Record 11 of Set 9 | bilma
# Processing Record 12 of Set 9 | berlevag
# Processing Record 13 of Set 9 | djibo
# Processing Record 14 of Set 9 | presidente medici
# Processing Record 15 of Set 9 | lebork
# Processing Record 16 of Set 9 | gizo
# Processing Record 17 of Set 9 | nadym
# Processing Record 18 of Set 9 | sao filipe
# Processing Record 19 of Set 9 | vilhena
# Processing Record 20 of Set 9 | pacific grove
# Processing Record 21 of Set 9 | oranjemund
# Processing Record 22 of Set 9 | nam tha
# City not found. Skipping...
# Processing Record 23 of Set 9 | luderitz
# Processing Record 24 of Set 9 | qaracala
# Processing Record 25 of Set 9 | vieste
# Processing Record 26 of Set 9 | tabou
# Processing Record 27 of Set 9 | beidao
# Processing Record 28 of Set 9 | soubre
# Processing Record 29 of Set 9 | bethel
# Processing Record 30 of Set 9 | forbes
# Processing Record 31 of Set 9 | nouadhibou
# Processing Record 32 of Set 9 | lermontovka
# Processing Record 33 of Set 9 | basco
# Processing Record 34 of Set 9 | shingu
# Processing Record 35 of Set 9 | roald
# Processing Record 36 of Set 9 | kampene
# Processing Record 37 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 9 | concarneau
# Processing Record 39 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 40 of Set 9 | nyurba
# Processing Record 41 of Set 9 | paralia
# Processing Record 42 of Set 9 | brasileia
# Processing Record 43 of Set 9 | dombarovskiy
# Processing Record 44 of Set 9 | liberia
# Processing Record 45 of Set 9 | wakkanai
# Processing Record 46 of Set 9 | kayes
# Processing Record 47 of Set 9 | noumea
# Processing Record 48 of Set 9 | lompoc
# Processing Record 49 of Set 9 | uribia
# Processing Record 50 of Set 9 | alofi
# Processing Record 1 of Set 10 | maamba
# Processing Record 2 of Set 10 | do rud
# City not found. Skipping...
# Processing Record 3 of Set 10 | baripada
# Processing Record 4 of Set 10 | raga
# Processing Record 5 of Set 10 | bonavista
# Processing Record 6 of Set 10 | fort frances
# Processing Record 7 of Set 10 | port blair
# Processing Record 8 of Set 10 | port-cartier
# Processing Record 9 of Set 10 | banikoara
# Processing Record 10 of Set 10 | west plains
# Processing Record 11 of Set 10 | rio gallegos
# Processing Record 12 of Set 10 | iqaluit
# Processing Record 13 of Set 10 | langxiang
# Processing Record 14 of Set 10 | tarbagatay
# Processing Record 15 of Set 10 | paamiut
# Processing Record 16 of Set 10 | montgomery
# Processing Record 17 of Set 10 | blythe
# Processing Record 18 of Set 10 | caernarfon
# Processing Record 19 of Set 10 | husavik
# Processing Record 20 of Set 10 | kulhudhuffushi
# Processing Record 21 of Set 10 | launceston
# Processing Record 22 of Set 10 | iracoubo
# Processing Record 23 of Set 10 | guaruja
# Processing Record 24 of Set 10 | metro
# Processing Record 25 of Set 10 | alma
# Processing Record 26 of Set 10 | wamba
# Processing Record 27 of Set 10 | pimampiro
# Processing Record 28 of Set 10 | kholodnyy
# Processing Record 29 of Set 10 | detchino
# Processing Record 30 of Set 10 | lanigan
# Processing Record 31 of Set 10 | pundaguitan
# Processing Record 32 of Set 10 | kyakhta
# Processing Record 33 of Set 10 | bell ville
# Processing Record 34 of Set 10 | misratah
# Processing Record 35 of Set 10 | darhan
# Processing Record 36 of Set 10 | shimoda
# Processing Record 37 of Set 10 | jiangyou
# Processing Record 38 of Set 10 | finnsnes
# Processing Record 39 of Set 10 | cedar city
# Processing Record 40 of Set 10 | yarim
# Processing Record 41 of Set 10 | umm kaddadah
# Processing Record 42 of Set 10 | puerto carreno
# Processing Record 43 of Set 10 | kyren
# Processing Record 44 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 10 | ratnagiri
# Processing Record 46 of Set 10 | healdsburg
# Processing Record 47 of Set 10 | pagudpud
# Processing Record 48 of Set 10 | slanic-moldova
# Processing Record 49 of Set 10 | caconda
# Processing Record 50 of Set 10 | tocopilla
# Processing Record 1 of Set 11 | thunder bay
# Processing Record 2 of Set 11 | mindelo
# Processing Record 3 of Set 11 | guacimo
# Processing Record 4 of Set 11 | noyabrsk
# Processing Record 5 of Set 11 | emba
# Processing Record 6 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 7 of Set 11 | kemijarvi
# Processing Record 8 of Set 11 | mitu
# Processing Record 9 of Set 11 | nanortalik
# Processing Record 10 of Set 11 | sur
# Processing Record 11 of Set 11 | gurupi
# Processing Record 12 of Set 11 | vostok
# Processing Record 13 of Set 11 | nortelandia
# Processing Record 14 of Set 11 | te anau
# Processing Record 15 of Set 11 | aquiraz
# Processing Record 16 of Set 11 | xinyang
# Processing Record 17 of Set 11 | sovetskiy
# Processing Record 18 of Set 11 | sioux lookout
# Processing Record 19 of Set 11 | nome
# Processing Record 20 of Set 11 | rio negrinho
# Processing Record 21 of Set 11 | eydhafushi
# Processing Record 22 of Set 11 | ladson
# Processing Record 23 of Set 11 | chokwe
# Processing Record 24 of Set 11 | lata
# Processing Record 25 of Set 11 | el sauzal
# Processing Record 26 of Set 11 | shalakusha
# Processing Record 27 of Set 11 | anamur
# Processing Record 28 of Set 11 | port lincoln
# Processing Record 29 of Set 11 | sechura
# Processing Record 30 of Set 11 | kieta
# Processing Record 31 of Set 11 | poyarkovo
# Processing Record 32 of Set 11 | ahipara
# Processing Record 33 of Set 11 | novoagansk
# Processing Record 34 of Set 11 | urengoy
# Processing Record 35 of Set 11 | reforma
# Processing Record 36 of Set 11 | corner brook
# Processing Record 37 of Set 11 | channel-port aux basques
# Processing Record 38 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 11 | codrington
# Processing Record 40 of Set 11 | sete lagoas
# Processing Record 41 of Set 11 | uruzgan
# Processing Record 42 of Set 11 | turukhansk
# Processing Record 43 of Set 11 | warri
# Processing Record 44 of Set 11 | avera
# Processing Record 45 of Set 11 | morant bay
# Processing Record 46 of Set 11 | meadville
# Processing Record 47 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 48 of Set 11 | ringkobing
# Processing Record 49 of Set 11 | cuiluan
# Processing Record 50 of Set 11 | tiznit
# Processing Record 1 of Set 12 | bilecik
# Processing Record 2 of Set 12 | walvis bay
# Processing Record 3 of Set 12 | nara
# Processing Record 4 of Set 12 | sorland
# Processing Record 5 of Set 12 | catalina
# Processing Record 6 of Set 12 | aitape
# Processing Record 7 of Set 12 | iralaya
# Processing Record 8 of Set 12 | portage
# Processing Record 9 of Set 12 | saint-joseph
# Processing Record 10 of Set 12 | nuuk
# Processing Record 11 of Set 12 | saint anthony
# Processing Record 12 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 12 | athens
# Processing Record 14 of Set 12 | qujing
# Processing Record 15 of Set 12 | oum hadjer
# Processing Record 16 of Set 12 | puyang
# Processing Record 17 of Set 12 | tungor
# Processing Record 18 of Set 12 | coffs harbour
# Processing Record 19 of Set 12 | grindavik
# Processing Record 20 of Set 12 | dungarpur
# Processing Record 21 of Set 12 | vanavara
# Processing Record 22 of Set 12 | tautira
# Processing Record 23 of Set 12 | makungu
# Processing Record 24 of Set 12 | peniche
# Processing Record 25 of Set 12 | mantua
# Processing Record 26 of Set 12 | tezu
# Processing Record 27 of Set 12 | bandarbeyla
# Processing Record 28 of Set 12 | sambava
# Processing Record 29 of Set 12 | korla
# Processing Record 30 of Set 12 | batemans bay
# Processing Record 31 of Set 12 | raudeberg
# Processing Record 32 of Set 12 | shreveport
# Processing Record 33 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 34 of Set 12 | bara
# Processing Record 35 of Set 12 | setermoen
# Processing Record 36 of Set 12 | lashio
# Processing Record 37 of Set 12 | chapais
# Processing Record 38 of Set 12 | arlit
# Processing Record 39 of Set 12 | panama city
# Processing Record 40 of Set 12 | emerald
# Processing Record 41 of Set 12 | vientiane
# Processing Record 42 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 12 | otane
# Processing Record 44 of Set 12 | indi
# Processing Record 45 of Set 12 | ginir
# Processing Record 46 of Set 12 | olafsvik
# Processing Record 47 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 12 | okhotsk
# Processing Record 49 of Set 12 | zhuhai
# Processing Record 50 of Set 12 | padang
# Processing Record 1 of Set 13 | quchan
# Processing Record 2 of Set 13 | amarante do maranhao
# Processing Record 3 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 4 of Set 13 | toccoa
# Processing Record 5 of Set 13 | daru
# Processing Record 6 of Set 13 | kayerkan
# Processing Record 7 of Set 13 | belmonte
# Processing Record 8 of Set 13 | pontes e lacerda
# Processing Record 9 of Set 13 | maragogi
# Processing Record 10 of Set 13 | pedreiras
# Processing Record 11 of Set 13 | mushie
# Processing Record 12 of Set 13 | zemio
# Processing Record 13 of Set 13 | bermeo
# Processing Record 14 of Set 13 | kiama
# Processing Record 15 of Set 13 | altamira
# Processing Record 16 of Set 13 | sulangan
# Processing Record 17 of Set 13 | grootfontein
# Processing Record 18 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 19 of Set 13 | basti
# Processing Record 20 of Set 13 | yeppoon
# Processing Record 21 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 13 | along
# Processing Record 23 of Set 13 | barbosa ferraz
# Processing Record 24 of Set 13 | asmar
# Processing Record 25 of Set 13 | kochki
# Processing Record 26 of Set 13 | izumo
# Processing Record 27 of Set 13 | tabat
# Processing Record 28 of Set 13 | cloquet
# Processing Record 29 of Set 13 | kawambwa
# Processing Record 30 of Set 13 | nizhniy baskunchak
# Processing Record 31 of Set 13 | khor
# Processing Record 32 of Set 13 | barcelos
# Processing Record 33 of Set 13 | aksu
# Processing Record 34 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 13 | zeya
# Processing Record 36 of Set 13 | luanda
# Processing Record 37 of Set 13 | koroni
# Processing Record 38 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 13 | sarkand
# Processing Record 40 of Set 13 | chilca
# Processing Record 41 of Set 13 | champoton
# Processing Record 42 of Set 13 | ilhabela
# Processing Record 43 of Set 13 | flic en flac
# Processing Record 44 of Set 13 | joshimath
# Processing Record 45 of Set 13 | mosetse
# Processing Record 46 of Set 13 | vila
# Processing Record 47 of Set 13 | saint-louis
# Processing Record 48 of Set 13 | gberia fotombu
# Processing Record 49 of Set 13 | birr
# Processing Record 50 of Set 13 | las lomas
# Processing Record 1 of Set 14 | egvekinot
# Processing Record 2 of Set 14 | praia da vitoria
# Processing Record 3 of Set 14 | baker city
# Processing Record 4 of Set 14 | sumter
# Processing Record 5 of Set 14 | lengshuijiang
# Processing Record 6 of Set 14 | assiniboia
# Processing Record 7 of Set 14 | esmeraldas
# Processing Record 8 of Set 14 | san nicolas
# Processing Record 9 of Set 14 | dzaoudzi
# Processing Record 10 of Set 14 | namakkal
# Processing Record 11 of Set 14 | galle
# Processing Record 12 of Set 14 | benghazi
# Processing Record 13 of Set 14 | isangel
# Processing Record 14 of Set 14 | palana
# Processing Record 15 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 14 | mato verde
# Processing Record 17 of Set 14 | tual
# Processing Record 18 of Set 14 | formosa
# Processing Record 19 of Set 14 | lafia
# Processing Record 20 of Set 14 | nkhata bay
# Processing Record 21 of Set 14 | marzuq
# Processing Record 22 of Set 14 | foshan
# Processing Record 23 of Set 14 | ode
# Processing Record 24 of Set 14 | buraydah
# Processing Record 25 of Set 14 | caceres
# Processing Record 26 of Set 14 | moerai
# Processing Record 27 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 28 of Set 14 | lethem
# Processing Record 29 of Set 14 | bambanglipuro
# Processing Record 30 of Set 14 | rudnyy
# Processing Record 31 of Set 14 | panacan
# Processing Record 32 of Set 14 | kuusamo
# Processing Record 33 of Set 14 | tabon
# Processing Record 34 of Set 14 | santa ana
# Processing Record 35 of Set 14 | aksarka
# Processing Record 36 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 37 of Set 14 | kijang
# Processing Record 38 of Set 14 | byron bay
# Processing Record 39 of Set 14 | fuyang
# Processing Record 40 of Set 14 | keti bandar
# Processing Record 41 of Set 14 | vesele
# Processing Record 42 of Set 14 | kashan
# Processing Record 43 of Set 14 | waipawa
# Processing Record 44 of Set 14 | tonstad
# Processing Record 45 of Set 14 | gigmoto
# Processing Record 46 of Set 14 | ishigaki
# Processing Record 47 of Set 14 | broome
# Processing Record 48 of Set 14 | tarazona
# Processing Record 49 of Set 14 | ust-tsilma
# Processing Record 50 of Set 14 | george
# Processing Record 1 of Set 15 | preobrazheniye
# Processing Record 2 of Set 15 | brandfort
# Processing Record 3 of Set 15 | havoysund
# Processing Record 4 of Set 15 | baherden
# Processing Record 5 of Set 15 | tumaco
# Processing Record 6 of Set 15 | port-gentil
# Processing Record 7 of Set 15 | maltahohe
# Processing Record 8 of Set 15 | la rioja
# Processing Record 9 of Set 15 | sergeyevka
# Processing Record 10 of Set 15 | bandrele
# Processing Record 11 of Set 15 | itamaraca
# Processing Record 12 of Set 15 | ler
# Processing Record 13 of Set 15 | pedasi
# Processing Record 14 of Set 15 | kimbe
# Processing Record 15 of Set 15 | ranong
# Processing Record 16 of Set 15 | rongcheng
# Processing Record 17 of Set 15 | mandan
# Processing Record 18 of Set 15 | lander
# Processing Record 19 of Set 15 | narsaq
# Processing Record 20 of Set 15 | lebyazhye
# Processing Record 21 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 22 of Set 15 | takahagi
# Processing Record 23 of Set 15 | edgewater
# Processing Record 24 of Set 15 | atasu
# Processing Record 25 of Set 15 | ende
# Processing Record 26 of Set 15 | beringovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 661

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dakar  14.6937  -17.4441     77.13        50           0
# 1   Punta Arenas -53.1500  -70.9167     42.91        70          40
# 2      Mahebourg -20.4081   57.7000     80.89        61          40
# 3  Volgorechensk  57.4393   41.1555     15.67        95          95
# 4   Puerto Ayora  -0.7393  -90.3518     66.54        98          95
# 5           Hilo  19.7297 -155.0900     69.53        90          20
# 6         Dingle  10.9995  122.6711     82.17        74          12
# 7         Inuvik  68.3499 -133.7218     -3.14        80         100
# 8        Rikitea -23.1203 -134.9692     74.43        80          73
# 9     Port Hardy  50.6996 -127.4199     37.58        93          40
#
#    Wind Speed Country Current Description                 Date
# 0       13.80      SN           clear sky  2022-11-27 07:51:07
# 1        3.44      CL    scattered clouds  2022-11-27 07:51:08
# 2       13.80      MU    scattered clouds  2022-11-27 07:47:07
# 3        6.11      RU     overcast clouds  2022-11-27 07:51:08
# 4        6.38      EC     overcast clouds  2022-11-27 07:51:09
# 5        3.44      US          few clouds  2022-11-27 07:51:09
# 6       10.25      PH          few clouds  2022-11-27 07:51:10
# 7        5.75      CA          light snow  2022-11-27 07:51:10
# 8        6.06      PF       broken clouds  2022-11-27 07:51:11
# 9       10.36      CA    scattered clouds  2022-11-27 07:51:11

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dakar      SN  14.6937  -17.4441     77.13        50           0
# 1   Punta Arenas      CL -53.1500  -70.9167     42.91        70          40
# 2      Mahebourg      MU -20.4081   57.7000     80.89        61          40
# 3  Volgorechensk      RU  57.4393   41.1555     15.67        95          95
# 4   Puerto Ayora      EC  -0.7393  -90.3518     66.54        98          95
# 5           Hilo      US  19.7297 -155.0900     69.53        90          20
# 6         Dingle      PH  10.9995  122.6711     82.17        74          12
# 7         Inuvik      CA  68.3499 -133.7218     -3.14        80         100
# 8        Rikitea      PF -23.1203 -134.9692     74.43        80          73
# 9     Port Hardy      CA  50.6996 -127.4199     37.58        93          40
#
#    Wind Speed Current Description                 Date
# 0       13.80           clear sky  2022-11-27 07:51:07
# 1        3.44    scattered clouds  2022-11-27 07:51:08
# 2       13.80    scattered clouds  2022-11-27 07:47:07
# 3        6.11     overcast clouds  2022-11-27 07:51:08
# 4        6.38     overcast clouds  2022-11-27 07:51:09
# 5        3.44          few clouds  2022-11-27 07:51:09
# 6       10.25          few clouds  2022-11-27 07:51:10
# 7        5.75          light snow  2022-11-27 07:51:10
# 8        6.06       broken clouds  2022-11-27 07:51:11
# 9       10.36    scattered clouds  2022-11-27 07:51:11

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# Date                    object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
